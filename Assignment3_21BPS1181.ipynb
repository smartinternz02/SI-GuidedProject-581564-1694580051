# %%
#Raghav S
#21BPS1181

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Dataset

# %%
df=pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.corr()
# Out:
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_23600\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# ...

# %%
df.corr().Pclass.sort_values(ascending=False)
# Out:
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_23600\2321911039.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().Pclass.sort_values(ascending=False)
# Pclass         1.000000
# SibSp          0.083081
# Parch          0.018443
# PassengerId   -0.035144
# Survived      -0.338481
# Age           -0.369226
# Fare          -0.549500
# Name: Pclass, dtype: float64

# %% [markdown]
# ### Null Values

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2=df.fillna(method='bfill')

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# dtype: bool

# %%
df3=df2.fillna(value=0)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df3.Pclass.nunique()
# Out:
# 3

# %%
df3.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df3.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
plt.scatter(df3["Age"],df3["Fare"])

# %%
sns.heatmap(df3.corr(),annot=True)
# Out:
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_23600\4142263269.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df3.corr(),annot=True)
# <Axes: >

# %%
sns.pairplot(df3)

# %%
sns.barplot(x=df3["Pclass"],y=df3["Fare"],errorbar=('ci', 0))
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ### Outiler Detection

# %%
sns.boxplot(df3["Age"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["PassengerId"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["Survived"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["Pclass"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["SibSp"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["Parch"])
# Out:
# <Axes: >

# %%
sns.boxplot(df3["Fare"])
# Out:
# <Axes: >

# %% [markdown]
# ### Splitting dependent and Independent Variables

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S

# %%
x=df3.drop(columns=["Survived","Name","Ticket","Cabin"],axis=1)
x.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S

# %%
x.shape
# Out:
# (891, 11)

# %%
y=df3["Survived"]

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
# ### Encoding

# %%
x.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1       3    male  22.0      1      0   7.2500        S
# 1            2       1  female  38.0      1      0  71.2833        C
# 2            3       3  female  26.0      0      0   7.9250        S
# 3            4       1  female  35.0      1      0  53.1000        S
# 4            5       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
x["Sex"]=le.fit_transform(x["Sex"])

# %%
x["Embarked"]=le.fit_transform(x["Embarked"])

# %%
x.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1       3    1  22.0      1      0   7.2500         2
# 1            2       1    0  38.0      1      0  71.2833         0
# 2            3       3    0  26.0      0      0   7.9250         2
# 3            4       1    0  35.0      1      0  53.1000         2
# 4            5       3    1  35.0      0      0   8.0500         2

# %%
print(le.classes_)
# Out:
# ['C' 'Q' 'S']

# %%
mapping=dict(zip(le.classes_,range(len(le.classes_))))

# %%
mapping
# Out:
# {'C': 0, 'Q': 1, 'S': 2}

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms=MinMaxScaler()

# %%
x_scaled=pd.DataFrame(ms.fit_transform(x),columns=x.columns)

# %%
x_scaled.head()
# Out:
#    PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0     0.000000     1.0  1.0  0.271174  0.125    0.0  0.014151       1.0
# 1     0.001124     0.0  0.0  0.472229  0.125    0.0  0.139136       0.0
# 2     0.002247     1.0  0.0  0.321438  0.000    0.0  0.015469       1.0
# 3     0.003371     0.0  0.0  0.434531  0.125    0.0  0.103644       1.0
# 4     0.004494     1.0  1.0  0.434531  0.000    0.0  0.015713       1.0

# %% [markdown]
# ### Test Train Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (712, 8) (179, 8) (712,) (179,)
